# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import pos_tag
from collections import Counter

# %%
text = """
Natural Language Processing (NLP) is a subfield of artificial intelligence (AI) 
concerned with the interactions between computers and human language. 
It involves applying algorithms to identify and extract the natural language rules.
"""

# %%
# Step a: Tokenization
tokens = word_tokenize(text)
print("Tokenized Words:")
print(tokens)
# Out:
# Tokenized Words:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'subfield', 'of', 'artificial', 'intelligence', '(', 'AI', ')', 'concerned', 'with', 'the', 'interactions', 'between', 'computers', 'and', 'human', 'language', '.', 'It', 'involves', 'applying', 'algorithms', 'to', 'identify', 'and', 'extract', 'the', 'natural', 'language', 'rules', '.']

# %%
# Step b: Word Frequency Count
word_freq = Counter(tokens)
print("\nWord Frequency:")
for word, freq in word_freq.items():
    print(f"{word}: {freq}")
# Out:
# Word Frequency:
# Natural: 1
# Language: 1
# Processing: 1
# (: 2
# NLP: 1
# ): 2
# is: 1
# a: 1
# subfield: 1
# of: 1
# artificial: 1
# intelligence: 1
# AI: 1
# concerned: 1
# with: 1
# the: 2
# interactions: 1
# between: 1
# computers: 1
# and: 2
# human: 1
# language: 2
# .: 2
# It: 1
# involves: 1
# applying: 1
# algorithms: 1
# to: 1
# identify: 1
# extract: 1
# natural: 1
# rules: 1

# %%
# Step c: Remove Stop Words
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words and word.isalnum()]
print("\nFiltered Tokens (Stop words removed):")
print(filtered_tokens)
# Out:
# Filtered Tokens (Stop words removed):
# ['Natural', 'Language', 'Processing', 'NLP', 'subfield', 'artificial', 'intelligence', 'AI', 'concerned', 'interactions', 'computers', 'human', 'language', 'involves', 'applying', 'algorithms', 'identify', 'extract', 'natural', 'language', 'rules']

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Error loading averaged_perceptron_tagger: <urlopen error
# [nltk_data]     [Errno -3] Temporary failure in name resolution>
# False

# %%
# Step d: POS Tagging

nltk.download('averaged_perceptron_tagger')

pos_tags = pos_tag(filtered_tokens)
print("\nPart of Speech Tags:")
for word, tag in pos_tags:
    print(f"{word}: {tag}")
# Out:
# [nltk_data] Error loading averaged_perceptron_tagger: <urlopen error
# [nltk_data]     [Errno -3] Temporary failure in name resolution>
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipykernel_32/3839665474.py in <cell line: 0>()
#       3 nltk.download('averaged_perceptron_tagger')
#       4
# ----> 5 pos_tags = pos_tag(filtered_tokens)
#       6 print("\nPart of Speech Tags:")
#       7 for word, tag in pos_tags:
#
# /usr/local/lib/python3.11/dist-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#     170
#
# /usr/local/lib/python3.11/dist-packages/nltk/tag/__init__.py in _get_tagger(lang)
#     108         tagger = PerceptronTagger(lang=lang)
#     109     else:
# ...
